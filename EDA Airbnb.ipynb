# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns

# %%
#using pandas library and 'read_csv' function to read BlackFriday csv file as file already formated for us from Kaggle
airbnb=pd.read_csv("listings_cleaned.csv")
#examing head of BlackFriday csv file 
airbnb.head(3)
# Out:
# C:\Users\doogi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (46,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       id  host_since host_response_time host_response_rate  host_is_superhost  \
# 0  35797  2010-06-28            unknown            unknown                0.0
# 1  44616  2010-08-09       within a day             50-89%                0.0
# 2  56074  2010-10-19     within an hour               100%                1.0
#
#    host_listings_count  host_identity_verified neighbourhood_cleansed  \
# 0                  2.0                     1.0  Cuajimalpa de Morelos
# 1                  9.0                     1.0             Cuauhtémoc
# 2                  2.0                     1.0             Cuauhtémoc
#
#   property_type        room_type  ...  white_goods elevator  gym  parking  \
# 0         House  Entire home/apt  ...          1.0      0.0  0.0      1.0
# 1         House  Entire home/apt  ...          1.0      0.0  0.0      1.0
# 2         House  Entire home/apt  ...          0.0      1.0  0.0      1.0
#
#    host_greeting  internet  long_term_stays  private_entrance  \
# 0            0.0       1.0              0.0               0.0
# 1            1.0       1.0              1.0               0.0
# 2            0.0       1.0              1.0               0.0
#
#    time_since_first_review time_since_last_review
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                 4+ years              2-8 weeks
#
# [3 rows x 48 columns]
